# %% [markdown]
# ---
# # Input

# %%
# Basic Libraries
import bs4 as bs
import urllib.request
import re

import nltk
from nltk import bigrams,trigrams
from collections import defaultdict

# %%
raw_html = urllib.request.urlopen('https://en.wikipedia.org/wiki/Tennis')
raw_html = raw_html.read()

article_html = bs.BeautifulSoup(raw_html, 'lxml')
article_paragraphs = article_html.find_all('p')
article_text = ''

for para in article_paragraphs:
    article_text += para.text

article_text = article_text.lower()
article_text = re.sub(r'[^A-Za-z. ]', '', article_text)
article_text
# Out:
# 'tennis is a racket sport that can be played individually against a single opponent singles or between two teams of two players each doubles. each player uses a tennis racket that is strung with cord to strike a hollow rubber ball covered with felt over or around a net and into the opponents court. the object of the game is to maneuver the ball in such a way that the opponent is not able to play a valid return. the player who is unable to return the ball will not gain a point while the opposite player will.tennis is an olympic sport and is played at all levels of society and at all ages. the sport can be played by anyone who can hold a racket including wheelchair users. the modern game of tennis originated in birmingham england in the late th century as lawn tennis. it had close connections both to various field lawn games such as croquet and bowls as well as to the older racket sport today called real tennis. during most of the th century in fact the term tennis referred to real tennis not lawn tennis.the rules of modern tennis have changed little since the s. two exceptions are that from  to  the server had to keep one foot on the ground at all times and the adoption of the tiebreak in the s. a recent addition to professional tennis has been the adoption of electronic review technology coupled with a pointchallenge system which allows a player to contest the line call of a point a system known as hawkeye.tennis is played by millions of recreational players and is also a popular worldwide spectator sport. the four grand slam tournaments also referred to as the majors are especially popular the australian open played on hard courts the french open played on red clay courts wimbledon played on grass courts and the us open also played on hard courts.historians believe that the games ancient origin lay in th century northern france where a ball was struck with the palm of the hand. louis x of france was a keen player of jeu de paume game of the palm which evolved into real tennis and became notable as the first person to construct indoor tennis courts in the modern style. louis was unhappy with playing tennis outdoors and accordingly had indoor enclosed courts made in paris around the end of the th century. in due course this design spread across royal palaces all over europe. in june  at vincennes valdemarne and following a particularly exhausting game louis drank a large quantity of cooled wine and subsequently died of either pneumonia or pleurisy although there was also suspicion of poisoning. because of the contemporary accounts of his death louis x is historys first tennis player known by name. another of the early enthusiasts of the game was king charles v of france who had a court set up at the louvre palace.it was not until the th century that rackets came into use and the game began to be called tennis from the french term tenez which can be translated as hold receive or take an interjection used as a call from the server to his opponent. it was popular in england and france although the game was only played indoors where the ball could be hit off the wall. henry viii of england was a big fan of this game which is now known as real tennis. during the th and early th centuries as real tennis declined new racket sports emerged in england.the invention of the first lawn mower in  in britain is believed to have been a catalyst for the preparation of modernstyle grass courts sporting ovals playing fields pitches greens etc. this in turn led to the codification of modern rules for many sports including lawn tennis most football codes lawn bowls and others.between  and  harry gem a solicitor and his friend augurio perera developed a game that combined elements of racquets and the basque ball game pelota which they played on pereras croquet lawn in birmingham in england. in  along with two local doctors they founded the worlds first tennis club on avenue road leamington spa. this is where lawn tennis was used as a name of activi ...

# %% [markdown]
# ---
# # Preprocessing

# %%
tokenized_sent = nltk.word_tokenize(article_text)
tokenized_sent
# Out:
# ['tennis',
#  'is',
#  'a',
#  'racket',
#  'sport',
#  'that',
#  'can',
#  'be',
#  'played',
#  'individually',
#  'against',
#  'a',
#  'single',
#  'opponent',
#  'singles',
#  'or',
#  'between',
#  'two',
#  'teams',
#  'of',
#  'two',
#  'players',
#  'each',
#  'doubles',
#  '.',
#  'each',
#  'player',
#  'uses',
#  'a',
#  'tennis',
#  'racket',
#  'that',
#  'is',
#  'strung',
#  'with',
#  'cord',
#  'to',
#  'strike',
#  'a',
#  'hollow',
#  'rubber',
#  'ball',
#  'covered',
#  'with',
#  'felt',
#  'over',
#  'or',
#  'around',
#  'a',
#  'net',
#  'and',
#  'into',
#  'the',
#  'opponents',
#  'court',
#  '.',
#  'the',
#  'object',
#  'of',
#  'the',
#  'game',
#  'is',
#  'to',
#  'maneuver',
#  'the',
#  'ball',
#  'in',
#  'such',
#  'a',
#  'way',
#  'that',
#  'the',
#  'opponent',
#  'is',
#  'not',
#  'able',
#  'to',
#  'play',
#  'a',
#  'valid',
#  'return',
#  '.',
#  'the',
#  'player',
#  'who',
#  'is',
#  'unable',
#  'to',
#  'return',
#  'the',
#  'ball',
#  'will',
#  'not',
#  'gain',
#  'a',
#  'point',
#  'while',
#  'the',
#  'opposite',
#  'player',
#  'will.tennis',
#  'is',
#  'an',
#  'olympic',
#  'sport',
#  'and',
#  'is',
#  'played',
#  'at',
#  'all',
#  'levels',
#  'of',
#  'society',
#  'and',
#  'at',
#  'all',
#  'ages',
#  '.',
#  'the',
#  'sport',
#  'can',
#  'be',
#  'played',
#  'by',
#  'anyone',
#  'who',
#  'can',
#  'hold',
#  'a',
#  'racket',
#  'including',
#  'wheelchair',
#  'users',
#  '.',
#  'the',
#  'modern',
#  'game',
#  'of',
#  'tennis',
#  'originated',
#  'in',
#  'birmingham',
#  'england',
#  'in',
#  'the',
#  'late',
#  'th',
#  'century',
#  'as',
#  'lawn',
#  'tennis',
#  '.',
#  'it',
#  'had',
#  'close',
#  'connections',
#  'both',
#  'to',
#  'various',
#  'field',
#  'lawn',
#  'games',
#  'such',
#  'as',
#  'croquet',
#  'and',
#  'bowls',
#  'as',
#  'well',
#  'as',
#  'to',
#  'the',
#  'older',
#  'racket',
#  'sport',
#  'today',
#  'called',
#  'real',
#  'tennis',
#  '.',
#  'during',
#  'most',
#  'of',
#  'the',
#  'th',
#  'century',
#  'in',
#  'fact',
#  'the',
#  'term',
#  'tennis',
#  'referred',
#  'to',
#  'real',
#  'tennis',
#  'not',
#  'lawn',
#  'tennis.the',
#  'rules',
#  'of',
#  'modern',
#  'tennis',
#  'have',
#  'changed',
#  'little',
#  'since',
#  'the',
#  's.',
#  'two',
#  'exceptions',
#  'are',
#  'that',
#  'from',
#  'to',
#  'the',
#  'server',
#  'had',
#  'to',
#  'keep',
#  'one',
#  'foot',
#  'on',
#  'the',
#  'ground',
#  'at',
#  'all',
#  'times',
#  'and',
#  'the',
#  'adoption',
#  'of',
#  'the',
#  'tiebreak',
#  'in',
#  'the',
#  's.',
#  'a',
#  'recent',
#  'addition',
#  'to',
#  'professional',
#  'tennis',
#  'has',
#  'been',
#  'the',
#  'adoption',
#  'of',
#  'electronic',
#  'review',
#  'technology',
#  'coupled',
#  'with',
#  'a',
#  'pointchallenge',
#  'system',
#  'which',
#  'allows',
#  'a',
#  'player',
#  'to',
#  'contest',
#  'the',
#  'line',
#  'call',
#  'of',
#  'a',
#  'point',
#  'a',
#  'system',
#  'known',
#  'as',
#  'hawkeye.tennis',
#  'is',
#  'played',
#  'by',
#  'millions',
#  'of',
#  'recreational',
#  'players',
#  'and',
#  'is',
#  'also',
#  'a',
#  'popular',
#  'worldwide',
#  'spectator',
#  'sport',
#  '.',
#  'the',
#  'four',
#  'grand',
#  'slam',
#  'tournaments',
#  'also',
#  'referred',
#  'to',
#  'as',
#  'the',
#  'majors',
#  'are',
#  'especially',
#  'popular',
#  'the',
#  'australian',
#  'open',
#  'played',
#  'on',
#  'hard',
#  'courts',
#  'the',
#  'french',
#  'open',
#  'played',
#  'on',
#  'red',
#  'clay',
#  'courts',
#  'wimbledon',
#  'played',
#  'on',
#  'grass',
#  'courts',
#  'and',
#  'the',
#  'us',
#  'open',
#  'also',
#  'played',
#  'on',
#  'hard',
#  'courts.historians',
#  'believe',
#  'that',
#  'the',
#  'games',
#  'ancient',
#  'origin',
#  'lay',
#  'in',
#  'th',
#  'century',
#  'northern',
#  'france',
#  'where',
#  'a',
#  'ball',
#  'was',
#  'struck',
#  'with',
#  'the',
#  'palm',
#  'of',
#  'the',
#  'hand',
#  '.',
#  'louis',
#  'x',
#  'of',
#  'france',
#  'was',
#  'a',
#  'keen',
#  'player',
#  'of',
#  'jeu',
#  'de',
#  'paume',
#  'game',
#  'of',
#  'the',
#  'palm',
#  'which',
#  'evolved',
#  'into',
#  'real',
#  'tennis',
#  'and',
#  'became',
#  'notable',
#  'as',
#  'the',
#  'first',
#  'person',
#  'to',
#  'construct',
#  'indoor',
#  'tennis',
#  'courts',
#  'in',
#  'the',
#  'modern',
#  'style',
#  '.',
#  'louis',
#  'was',
#  'unhappy',
#  'with',
#  'playing',
#  'tennis',
#  'outdoors',
#  'and',
#  'accordingly',
#  'had',
#  'indoor',
#  'enclosed',
#  'courts',
#  'made',
#  'in',
#  'paris',
#  'around',
#  'the',
#  'end',
#  'of',
#  'the',
#  'th',
#  'century',
#  '.',
#  'in',
#  'due',
#  'course',
#  'this',
#  'design',
#  'spread',
#  'across',
#  'royal',
#  'palaces',
#  'all',
#  'over',
#  'europe',
#  '.',
#  'in',
#  'june',
#  'at',
#  'vincennes',
#  'valdemarne',
#  'and',
#  'following',
#  'a',
#  'particularly',
#  'exhausting',
#  'game',
#  'louis',
#  'drank',
#  'a',
#  'large',
#  'quantity',
#  'of',
#  'cooled',
#  'wine',
#  'and',
#  'subsequently',
#  'died',
#  'of',
#  'either',
#  'pneumonia',
#  'or',
#  'pleurisy',
#  'although',
#  'there',
#  'was',
#  'also',
#  'suspicion',
#  'of',
#  'poisoning',
#  '.',
#  'because',
#  'of',
#  'the',
#  'contemporary',
#  'accounts',
#  'of',
#  'his',
#  'death',
#  'louis',
#  'x',
#  'is',
#  'historys',
#  'first',
#  'tennis',
#  'player',
#  'known',
#  'by',
#  'name',
#  '.',
#  'another',
#  'of',
#  'the',
#  'early',
#  'enthusiasts',
#  'of',
#  'the',
#  'game',
#  'was',
#  'king',
#  'charles',
#  'v',
#  'of',
#  'france',
#  'who',
#  'had',
#  'a',
#  'court',
#  'set',
#  'up',
#  'at',
#  'the',
#  'louvre',
#  'palace.it',
#  'was',
#  'not',
#  'until',
#  'the',
#  'th',
#  'century',
#  'that',
#  'rackets',
#  'came',
#  'into',
#  'use',
#  'and',
#  'the',
#  'game',
#  'began',
#  'to',
#  'be',
#  'called',
#  'tennis',
#  'from',
#  'the',
#  'french',
#  'term',
#  'tenez',
#  'which',
#  'can',
#  'be',
#  'translated',
#  'as',
#  'hold',
#  'receive',
#  'or',
#  'take',
#  'an',
#  'interjection',
#  'used',
#  'as',
#  'a',
#  'call',
#  'from',
#  'the',
#  'server',
#  'to',
#  'his',
#  'opponent',
#  '.',
#  'it',
#  'was',
#  'popular',
#  'in',
#  'england',
#  'and',
#  'france',
#  'although',
#  'the',
#  'game',
#  'was',
#  'only',
#  'played',
#  'indoors',
#  'where',
#  'the',
#  'ball',
#  'could',
#  'be',
#  'hit',
#  'off',
#  'the',
#  'wall',
#  '.',
#  'henry',
#  'viii',
#  'of',
#  'england',
#  'was',
#  'a',
#  'big',
#  'fan',
#  'of',
#  'this',
#  'game',
#  'which',
#  'is',
#  'now',
#  'known',
#  'as',
#  'real',
#  'tennis',
#  '.',
#  'during',
#  'the',
#  'th',
#  'and',
#  'early',
#  'th',
#  'centuries',
#  'as',
#  'real',
#  'tennis',
#  'declined',
#  'new',
#  'racket',
#  'sports',
#  'emerged',
#  'in',
#  'england.the',
#  'invention',
#  'of',
#  'the',
#  'first',
#  'lawn',
#  'mower',
#  'in',
#  'in',
#  'britain',
#  'is',
#  'believed',
#  'to',
#  'have',
#  'been',
#  'a',
#  'catalyst',
#  'for',
#  'the',
#  'preparation',
#  'of',
#  'modernstyle',
#  'grass',
#  'courts',
#  'sporting',
#  'ovals',
#  'playing',
#  'fields',
#  'pitches',
#  'greens',
#  'etc',
#  '.',
#  'this',
#  'in',
#  'turn',
#  'led',
#  'to',
#  'the',
#  'codification',
#  'of',
#  'modern',
#  'rules',
#  'for',
#  'many',
#  'sports',
#  'including',
#  'lawn',
#  'tennis',
#  'most',
#  'football',
#  'codes',
#  'lawn',
#  'bowls',
#  'and',
#  'others.between',
#  'and',
#  'harry',
#  'gem',
#  'a',
#  'solicitor',
#  'and',
#  'his',
#  'friend',
#  'augurio',
#  'perera',
#  'developed',
#  'a',
#  'game',
#  'that',
#  'combined',
#  'elements',
#  'of',
#  'racquets',
#  'and',
#  'the',
#  'basque',
#  'ball',
#  'game',
#  'pelota',
#  'which',
#  'they',
#  'played',
#  'on',
#  'pereras',
#  'croquet',
#  'lawn',
#  'in',
#  'birmingham',
#  'in',
#  'england',
#  '.',
#  'in',
#  'along',
#  'with',
#  'two',
#  'local',
#  'doctors',
#  'they',
#  'founded',
#  'the',
#  'worlds',
#  'first',
#  'tennis',
#  'club',
#  'on',
#  'avenue',
#  'road',
#  'leamington',
#  'spa',
#  '.',
#  'this',
#  'is',
#  'where',
#  'lawn',
#  'tennis',
#  'was',
#  'used',
#  'as',
#  'a',
#  'name',
#  'of',
#  'activity',
#  'by',
#  'a',
#  'club',
#  'for',
#  'the',
#  'first',
#  'time',
#  '.',
#  'after',
#  'leamington',
#  'the',
#  'second',
#  'club',
#  'to',
#  'take',
#  'up',
#  'the',
#  'game',
#  'of',
#  'lawn',
#  'tennis',
#  'appears',
#  'to',
#  'have',
#  'been',
#  'the',
#  'edgbaston',
#  'archery',
#  'and',
#  'croquet',
#  'society',
#  'also',
#  'in',
#  'birmingham.in',
#  'tennis',
#  'a',
#  'cultural',
#  'history',
#  'heiner',
#  'gillmeister',
#  'reveals',
#  'that',
#  'on',
#  'december',
#  'british',
#  'army',
#  'officer',
#  'walter',
#  'clopton',
#  'wingfield',
#  'wrote',
#  'to',
#  'harry',
#  'gem',
#  'commenting',
#  'that',
#  'he',
#  'wingfield',
#  'had',
#  'been',
#  'experimenting',
#  'with',
#  'his',
#  'version',
#  'of',
#  'lawn',
#  'tennis',
#  'for',
#  'a',
#  'year',
#  'and',
#  'a',
#  'half',
#  '.',
#  'in',
#  'december',
#  'wingfield',
#  'designed',
#  'and',
#  'patented',
#  'a',
#  'game',
#  'which',
#  'he',
#  'called',
#  'sphairistik',
#  'greek',
#  'meaning',
#  'ballplaying',
#  'and',
#  'was',
#  'soon',
#  'known',
#  'simply',
#  'as',
#  'sticky',
#  'for',
#  'the',
#  'amusement',
#  'of',
#  'guests',
#  'at',
#  'a',
#  'garden',
#  'party',
#  'on',
#  'his',
#  'friends',
#  'estate',
#  'of',
#  'nantclwyd',
#  'hall',
#  'in',
#  'llanelidan',
#  'wales',
#  '.',
#  'according',
#  'to',
#  'r.',
#  'd.',
#  'c.',
#  'evans',
#  'turfgrass',
#  'agronomist',
#  'sports',
#  'historians',
#  'all',
#  'agree',
#  'that',
#  'wingfield',
#  'deserves',
#  'much',
#  'of',
#  'the',
#  'credit',
#  'for',
#  'the',
#  'development',
#  'of',
#  'modern',
#  'tennis',
#  '.',
#  'according',
#  'to',
#  'honor',
#  'godfrey',
#  'museum',
#  'curator',
#  'at',
#  'wimbledon',
#  'wingfield',
#  'popularized',
#  'this',
#  'game',
#  'enormously',
#  '.',
#  'he',
#  'produced',
#  'a',
#  'boxed',
#  'set',
#  'which',
#  'included',
#  'a',
#  'net',
#  'poles',
#  'rackets',
#  'balls',
#  'for',
#  'playing',
#  'the',
#  'game',
#  'and',
#  'most',
#  'importantly',
#  'you',
#  'had',
#  'his',
#  'rules',
#  '.',
#  'he',
#  'was',
#  'absolutely',
#  'terrific',
#  'at',
#  'marketing',
#  'and',
#  'he',
#  'sent',
#  'his',
#  'game',
#  'all',
#  'over',
#  'the',
#  'world',
#  '.',
#  'he',
#  'had',
#  'very',
#  'good',
#  'connections',
#  'with',
#  'the',
#  'clergy',
#  'the',
#  'law',
#  'profession',
#  'and',
#  'the',
#  'aristocracy',
#  'and',
#  'he',
#  'sent',
#  'thousands',
#  'of',
#  'sets',
#  'out',
#  'in',
#  'the',
#  'first',
#  'year',
#  'or',
#  'so',
#  'in',
#  '.',
#  'the',
#  'worlds',
#  'oldest',
#  'annual',
#  'tennis',
#  'tournament',
#  'took',
#  'place',
#  'at',
#  'leamington',
#  'lawn',
#  'tennis',
#  'club',
#  'in',
#  'birmingham',
#  'in',
#  '.',
#  'this',
#  'was',
#  'three',
#  'years',
#  'before',
#  'the',
#  'all',
#  'england',
#  'lawn',
#  'tennis',
#  'and',
#  'croquet',
#  'club',
#  'would',
#  'hold',
#  'its',
#  'first',
#  'championships',
#  'at',
#  'wimbledon',
#  'in',
#  '.',
#  'the',
#  ...]

# %% [markdown]
# ---
# # Generating N-Gram Model

# %% [markdown]
# ---
# # 2-Gram

# %%
# Create a placeholder for model
model_2_gram = defaultdict(lambda: defaultdict(lambda: 0))

# Count frequency of co-occurance  
for w1, w2 in bigrams(tokenized_sent):
    model_2_gram[(w1)][w2] += 1

# Let's transform the counts to probabilities
for w1 in model_2_gram:
    total_count = float(sum(model_2_gram[w1].values()))
    for w2 in model_2_gram[w1]:
        model_2_gram[w1][w2] /= total_count

# %%
model_2_gram
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'tennis': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'is': 0.031007751937984496,
#                           'racket': 0.015503875968992248,
#                           'originated': 0.007751937984496124,
#                           '.': 0.08527131782945736,
#                           'referred': 0.007751937984496124,
#                           'not': 0.007751937984496124,
#                           'have': 0.007751937984496124,
#                           'has': 0.007751937984496124,
#                           'and': 0.023255813953488372,
#                           'courts': 0.007751937984496124,
#                           'outdoors': 0.007751937984496124,
#                           'player': 0.046511627906976744,
#                           'from': 0.007751937984496124,
#                           'declined': 0.007751937984496124,
#                           'most': 0.007751937984496124,
#                           'club': 0.015503875968992248,
#                           'was': 0.015503875968992248,
#                           'appears': 0.007751937984496124,
#                           'a': 0.015503875968992248,
#                           'for': 0.015503875968992248,
#                           'tournament': 0.023255813953488372,
#                           'after': 0.007751937984496124,
#                           'court': 0.015503875968992248,
#                           'organization': 0.007751937984496124,
#                           'association': 0.05426356589147287,
#                           'players': 0.06201550387596899,
#                           'federation': 0.046511627906976744,
#                           'withdrew': 0.007751937984496124,
#                           'as': 0.007751937984496124,
#                           'tour': 0.007751937984496124,
#                           'circuit': 0.007751937984496124,
#                           'hall': 0.007751937984496124,
#                           'memorabilia': 0.007751937984496124,
#                           'stems': 0.007751937984496124,
#                           'the': 0.007751937984496124,
#                           'rackets': 0.007751937984496124,
#                           'balls': 0.023255813953488372,
#                           'must': 0.007751937984496124,
#                           'balls.advanced': 0.007751937984496124,
#                           'shoes': 0.007751937984496124,
#                           'sphairistike': 0.007751937984496124,
#                           'scores': 0.007751937984496124,
#                           'game': 0.007751937984496124,
#                           'whenever': 0.007751937984496124,
#                           'format': 0.007751937984496124,
#                           'can': 0.007751937984496124,
#                           'started': 0.007751937984496124,
#                           'rules': 0.015503875968992248,
#                           'professionals': 0.007751937984496124,
#                           'by': 0.007751937984496124,
#                           'often': 0.007751937984496124,
#                           'almost': 0.007751937984496124,
#                           'playing': 0.007751937984496124,
#                           'match': 0.007751937984496124,
#                           'open': 0.007751937984496124,
#                           'especially': 0.007751937984496124,
#                           'rating': 0.007751937984496124,
#                           'events': 0.007751937984496124,
#                           'australia': 0.007751937984496124,
#                           'french': 0.007751937984496124,
#                           'tournaments': 0.031007751937984496,
#                           'competitions': 0.007751937984496124,
defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'played': 0.08163265306122448,
#                           'called': 0.061224489795918366,
#                           'translated': 0.02040816326530612,
#                           'hit': 0.04081632653061224,
#                           'approved': 0.02040816326530612,
#                           'named': 0.02040816326530612,
#                           'interlaced': 0.02040816326530612,
#                           'customized': 0.02040816326530612,
#                           'found.the': 0.02040816326530612,
#                           'delivered': 0.02040816326530612,
#                           'between': 0.02040816326530612,
#                           'up': 0.02040816326530612,
#                           'server': 0.02040816326530612,
#                           'legal': 0.02040816326530612,
#                           'assisted': 0.02040816326530612,
#                           'a': 0.04081632653061224,
#                           'calling': 0.02040816326530612,
#                           'questioned': 0.02040816326530612,
#                           'employed': 0.04081632653061224,
#                           'honest': 0.02040816326530612,
#                           'continuous': 0.02040816326530612,
#                           'determined': 0.02040816326530612,
#                           'stalling': 0.02040816326530612,
#                           'able': 0.02040816326530612,
#                           'pointing': 0.02040816326530612,
#                           'made': 0.04081632653061224,
#                           'coiled': 0.02040816326530612,
#                           'either': 0.02040816326530612,
#                           'executed': 0.02040816326530612,
#                           'used': 0.02040816326530612,
#                           'damaged': 0.02040816326530612,
#                           'organized': 0.02040816326530612,
#                           'matched': 0.02040816326530612,
#                           '.': 0.02040816326530612,
#                           'the': 0.061224489795918366,
#                           'top': 0.02040816326530612,
#                           'from': 0.02040816326530612,
#                           'among': 0.02040816326530612}),
#              'played': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'individually': 0.034482758620689655,
#                           'at': 0.034482758620689655,
#                           'by': 0.10344827586206896,
#                           'on': 0.2413793103448276,
#                           'indoors': 0.034482758620689655,
#                           'there': 0.034482758620689655,
#                           'under': 0.06896551724137931,
#                           'in': 0.06896551724137931,
#                           'with': 0.13793103448275862,
#                           '.': 0.10344827586206896,
#                           'indefinitely': 0.034482758620689655,
#                           'the': 0.034482758620689655,
#                           'from': 0.034482758620689655,
#                           'each': 0.034482758620689655}),
#              'individually': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'against': 1.0}),
#              'against': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'a': 0.25,
#                           'an': 0.25,
#                           'larger': 0.25,
#                           'it.for': 0.25}),
#              'single': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'opponent': 0.5, 'player': 0.5}),
#              'opponent': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'singles': 0.07142857142857142,
#                           'is': 0.2857142857142857,
#                           '.': 0.21428571428571427,
#                           'the': 0.07142857142857142,
#                           'five': 0.07142857142857142,
#                           'in': 0.07142857142857142,
#                           'as': 0.07142857142857142,
#                           'near': 0.07142857142857142,
#                           'or': 0.07142857142857142}),
#              'singles': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'or': 0.022727272727272728,
#                           'title': 0.022727272727272728,
#                           'championship': 0.022727272727272728,
#                           'championships': 0.022727272727272728,
#                           'matches': 0.022727272727272728,
#                           'net': 0.022727272727272728,
#                           'court': 0.022727272727272728,
#                           'sidelines': 0.022727272727272728,
#                           'play': 0.022727272727272728,
#                           'sideline': 0.022727272727272728,
#                           'over': 0.022727272727272728,
#                           'player': 0.06818181818181818,
#                           'and': 0.1590909090909091,
#                           'womens': 0.022727272727272728,
#                           'draws': 0.022727272727272728,
#                           'draw': 0.045454545454545456,
#                           'by': 0.022727272727272728,
#                           'champions': 0.045454545454545456,
#                           'players': 0.11363636363636363,
#                           'schedule': 0.022727272727272728,
#                           'ranking': 0.022727272727272728,
#                           'competition': 0.022727272727272728,
#                           'prize': 0.022727272727272728,
#                           'qualifying': 0.022727272727272728,
#                           'winner': 0.022727272727272728,
#                           'titles': 0.06818181818181818,
#                           'tennis': 0.022727272727272728,
#                           'doubles': 0.022727272727272728}),
#              'or': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {
#                           'between': 0.009900990099009901,
#                           'under': 0.009900990099009901,
#                           'would': 0.009900990099009901,
#                           'in': 0.019801980198019802,
#                           'other': 0.009900990099009901,
#                           'ranked': 0.009900990099009901,
#                           'compete': 0.009900990099009901,
#                           'atp': 0.009900990099009901,
#                           'championships': 0.009900990099009901,
#                           'enjoy': 0.009900990099009901,
#                           'grunting.while': 0.009900990099009901,
#                           'that': 0.019801980198019802,
#                           'earn': 0.009900990099009901,
#                           'outside': 0.009900990099009901,
#                           'receive': 0.009900990099009901,
#                           'an': 0.009900990099009901,
#                           'voted': 0.009900990099009901,
#                           'have': 0.009900990099009901,
#                           'he': 0.009900990099009901,
#                           'most': 0.009900990099009901}),
#              'each': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'doubles': 0.04,
#                           'player': 0.12,
#                           'club': 0.04,
#                           'hosted': 0.04,
#                           'became': 0.04,
#                           'now': 0.04,
#                           'year': 0.04,
#                           'side': 0.12,
#                           'side.the': 0.04,
#                           'baseline': 0.04,
#                           'point': 0.08,
#                           'game': 0.12,
#                           'taking': 0.04,
#                           'other': 0.04,
#                           'gender.most': 0.04,
#                           'event': 0.04,
#                           'tournament': 0.04,
#                           'year.premier': 0.04}),
#              'doubles': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'.': 0.05555555555555555,
#                           'match': 0.018518518518518517,
#                           'matches': 0.037037037037037035,
#                           'court': 0.018518518518518517,
#                           'sidelines': 0.037037037037037035,
#                           'sideline': 0.018518518518518517,
#                           'alley': 0.018518518518518517,
#                           'play': 0.018518518518518517,
#                           'team': 0.09259259259259259,
#                           'another': 0.018518518518518517,
#                           'style': 0.018518518518518517,
#                           'and': 0.05555555555555555,
#                           'by': 0.018518518518518517,
#                           'into': 0.018518518518518517,
# ...
#                          {'are': 1.0}),
#              'depending': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'on': 0.75, 'upon': 0.25}),
#              'position': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'they': 0.2,
#                           'after': 0.2,
#                           'north': 0.2,
#                           'on': 0.2,
#                           'or': 0.2}),
#              'serving': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'.': 0.4444444444444444,
#                           'player': 0.1111111111111111,
#                           'players': 0.1111111111111111,
#                           'has': 0.1111111111111111,
#                           'is': 0.1111111111111111,
#                           'remains': 0.1111111111111111}),
#              'if': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'none': 0.03333333333333333,
#                           'the': 0.5666666666666667,
#                           'at': 0.06666666666666667,
#                           'one': 0.03333333333333333,
#                           'in': 0.03333333333333333,
#                           'he': 0.03333333333333333,
#                           'they': 0.1,
#                           'however': 0.03333333333333333,
#                           'play': 0.03333333333333333,
#                           'a': 0.03333333333333333,
#                           'spinning': 0.03333333333333333}),
#              'none': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'of': 1.0}),
#              'upon': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'its': 0.25,
#                           'the': 0.25,
#                           'right': 0.25,
#                           'landing': 0.25}),
#              'mm': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'in': 0.5, 'wide': 0.5}),
#              'exception': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'of': 1.0}),
#              'practice': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'it': 1.0}),
#              'others.the': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'players': 1.0}),
#              'start': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'on': 0.2, 'anywhere': 0.2, 'of': 0.4, 'a': 0.2}),
#              'sides': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'of': 1.0}),
#              'designated': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              'opposing': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'player': 1.0}),
#              'receiver': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'.': 0.0625,
#                           'in': 0.0625,
#                           'may': 0.0625,
#                           'is': 0.125,
#                           'must': 0.0625,
#                           'wins': 0.0625,
#                           'not': 0.0625,
#                           'who': 0.0625,
#                           'does': 0.0625,
#                           'and': 0.0625,
#                           'fails': 0.0625,
#                           'has': 0.0625,
#                           'the': 0.0625,
#                           'before': 0.0625,
#                           'isnt': 0.0625}),
#              'choice': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'to': 0.5, 'of': 0.5}),
#              'coin': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'toss': 1.0}),
#              'toss': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'before': 1.0}),
#              'warmup': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'starts': 0.5, '.': 0.5}),
#              'starts': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'.': 0.3333333333333333,
#                           'behind': 0.3333333333333333,
#                           'a': 0.3333333333333333}),
#              'alternates': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'game': 1.0}),
#              'behind': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 0.5, 'and': 0.5}),
#              'anywhere': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'on': 1.0}),
#              'ready': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              'pace': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'of': 0.5, 'spin': 0.5}),
#              'server.for': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'a': 1.0}),
#              'legal': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 0.16666666666666666,
#                           'service.a': 0.16666666666666666,
#                           'service': 0.16666666666666666,
#                           'return': 0.5}),
#              'travel': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'over': 1.0}),
#              'without': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'touching': 0.6666666666666666,
#                           'time': 0.3333333333333333}),
#              'touching': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'it': 0.5, 'the': 0.5}),
#              'diagonally': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'opposite': 0.5, 'towards': 0.5}),
#              'box': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'.': 0.2,
#                           'this': 0.2,
#                           'or': 0.2,
#                           'without': 0.2,
#                           'then': 0.2}),
#              'hits': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              'lands': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'in': 1.0}),
#              'let': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'or': 0.2,
#                           'services': 0.2,
#                           'and': 0.2,
#                           'if': 0.2,
#                           'on': 0.2}),
#              'void': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'and': 1.0}),
#              'retakes': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'that': 1.0}),
#              'any': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'number': 0.125,
#                           'fixtures': 0.125,
#                           'official': 0.125,
#                           'given': 0.125,
#                           'of': 0.125,
#                           'other': 0.25,
#                           'male': 0.125}),
#              'services': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'in': 1.0}),
#              'always': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'treated': 0.2,
#                           'read': 0.4,
#                           'serving': 0.2,
#                           'allow': 0.2}),
#              'treated': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'as': 1.0}),
#              'voids': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'and': 1.0}),
#              'faults': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'.': 0.6666666666666666, 'and': 0.3333333333333333}),
#              'fault': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'is': 0.5, 'when': 0.25, 'the': 0.25}),
#              'falls': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'long': 0.5, 'in': 0.5}),
#              'does': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'not': 0.6666666666666666,
#                           'in': 0.3333333333333333}),
#              'touches': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              'extension': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'of': 1.0}),
#              'double': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'faults': 0.3333333333333333,
#                           'break': 0.3333333333333333,
#                           'the': 0.3333333333333333}),
#              'wins': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 0.5714285714285714,
#                           'a': 0.2857142857142857,
#                           'that': 0.14285714285714285}),
#              'considered': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'a': 0.2,
#                           'advantageous': 0.1,
#                           'part': 0.1,
#                           'by': 0.3,
#                           'more': 0.1,
#                           'to': 0.2}),
#              'service.a': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'legal': 1.0}),
#              'rally': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'in': 0.5, 'is': 0.5}),
#              'alternate': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'hitting': 1.0}),
#              'hitting': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 0.5714285714285714,
#                           'for': 0.14285714285714285,
#                           'it': 0.2857142857142857}),
#              'consists': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'of': 1.0}),
#              'servers': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'court': 0.3333333333333333,
#                           'being': 0.3333333333333333,
#                           'are': 0.3333333333333333}),
#              'bounced': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'twice': 0.5, 'also': 0.5}),
#              'twice': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'or': 0.3333333333333333, 'in': 0.6666666666666666}),
#              'fixtures': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'except': 1.0}),
#              'except': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 0.25, 'where': 0.25, 'for': 0.5}),
#              'team': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'can': 0.1,
#                           'to': 0.2,
#                           '.': 0.2,
#                           'does': 0.1,
#                           'each': 0.1,
#                           'tennis': 0.1,
#                           'captain': 0.1,
#                           'usa': 0.1}),
#              'row': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'.': 1.0}),
#              'other': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'players': 0.13333333333333333,
#                           'side': 0.06666666666666667,
#                           'tournaments': 0.06666666666666667,
#                           'to': 0.06666666666666667,
#                           'than': 0.06666666666666667,
#                           'external': 0.06666666666666667,
#                           'foot': 0.06666666666666667,
#                           'which': 0.06666666666666667,
#                           'court': 0.06666666666666667,
#                           'tour': 0.06666666666666667,
#                           'professional': 0.06666666666666667,
#                           'events': 0.06666666666666667,
#                           'individual': 0.06666666666666667,
#                           'legends..': 0.06666666666666667}),
#              'crosses': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'into': 1.0}),
#              'fail': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'to': 1.0}),
#              'loses': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'the': 1.0}),
#              'moves': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'to': 1.0}),
#              'point.a': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'game': 0.5, 'difficult': 0.5}),
#              'sequence': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'of': 1.0}),
#              'points': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'played': 0.047619047619047616,
#                           'in': 0.047619047619047616,
#                           'more': 0.047619047619047616,
#                           'are': 0.14285714285714285,
#                           'have': 0.09523809523809523,
#                           'set': 0.047619047619047616,
#                           'and': 0.14285714285714285,
#                           'to': 0.09523809523809523,
#                           'if': 0.047619047619047616,
#                           'culminating': 0.047619047619047616,
#                           '.': 0.09523809523809523,
#                           'earned': 0.09523809523809523,
#                           'wta': 0.047619047619047616}),
#              'least': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'four': 0.18181818181818182,
#                           'two': 0.18181818181818182,
#                           'three': 0.18181818181818182,
#                           'six': 0.09090909090909091,
#                           'one': 0.18181818181818182,
#                           'commonly': 0.09090909090909091,
#                           'five': 0.09090909090909091}),
#              'total': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'and': 0.3333333333333333,
#                           'prize': 0.3333333333333333,
#                           'player': 0.3333333333333333}),
#              'running': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'score': 0.5, 'the': 0.5}),
#              'score': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'of': 0.5714285714285714,
#                           'is': 0.07142857142857142,
#                           'first': 0.14285714285714285,
#                           '.': 0.07142857142857142,
#                           'in': 0.07142857142857142,
#                           'as': 0.07142857142857142}),
#              'described': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'in': 0.5, 'as': 0.5}),
#              ...})

# %% [markdown]
# ---
# # 3-Gram

# %%
# Create a placeholder for model
model_3_gram = defaultdict(lambda: defaultdict(lambda: 0))

# Count frequency of co-occurance  
for w1, w2, w3 in trigrams(tokenized_sent, pad_right=True, pad_left=True):
    model_3_gram[(w1, w2)][w3] += 1

# Let's transform the counts to probabilities
for w1_w2 in model_3_gram:
    total_count = float(sum(model_3_gram[w1_w2].values()))
    for w3 in model_3_gram[w1_w2]:
        model_3_gram[w1_w2][w3] /= total_count

# %%
model_3_gram
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {(None,
#               None): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'tennis': 1.0}),
#              (None,
#               'tennis'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'is': 1.0}),
#              ('tennis',
#               'is'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 0.5,
#                           'played': 0.25,
#                           'the': 0.25}),
#              ('is',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'racket': 0.07142857142857142,
#                           'let': 0.07142857142857142,
#                           'serve': 0.07142857142857142,
#                           'player': 0.07142857142857142,
#                           'relevant': 0.07142857142857142,
#                           'very': 0.07142857142857142,
#                           'diagonal': 0.07142857142857142,
#                           'way': 0.07142857142857142,
#                           'shot': 0.14285714285714285,
#                           'stroke': 0.14285714285714285,
#                           'break': 0.07142857142857142,
#                           'group': 0.07142857142857142}),
#              ('a',
#               'racket'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'sport': 0.3333333333333333,
#                           'including': 0.3333333333333333,
#                           'and': 0.3333333333333333}),
#              ('racket',
#               'sport'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'that': 0.5,
#                           'today': 0.5}),
#              ('sport',
#               'that'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'can': 1.0}),
#              ('that',
#               'can'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'be': 1.0}),
#              ('can',
#               'be'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'played': 0.36363636363636365,
#                           'translated': 0.09090909090909091,
#                           'up': 0.09090909090909091,
#                           'called': 0.09090909090909091,
#                           'coiled': 0.09090909090909091,
#                           'either': 0.09090909090909091,
#                           'executed': 0.09090909090909091,
#                           'used': 0.09090909090909091}),
#              ('be',
#               'played'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'individually': 0.25,
#                           'by': 0.5,
#                           'in': 0.25}),
#              ('played',
#               'individually'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'against': 1.0}),
#              ('individually',
#               'against'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 1.0}),
#              ('against',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'single': 1.0}),
#              ('a',
#               'single'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'opponent': 1.0}),
#              ('single',
#               'opponent'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'singles': 1.0}),
#              ('opponent',
#               'singles'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'or': 1.0}),
#              ('singles',
#               'or'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'between': 1.0}),
#              ('or',
#               'between'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'two': 1.0}),
#              ('between',
#               'two'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'teams': 1.0}),
#              ('two',
#               'teams'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'of': 1.0}),
#              ('teams',
#               'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'two': 1.0}),
#              ('of',
#               'two'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'players': 0.5,
#                           'male': 0.5}),
#              ('two',
#               'players'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'each': 0.3333333333333333,
#                           'or': 0.3333333333333333,
#                           'play': 0.3333333333333333}),
#              ('players',
#               'each'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'doubles': 1.0}),
#              ('each',
#               'doubles'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'.': 1.0}),
#              ('doubles',
#               '.'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'each': 0.3333333333333333,
#                           'this': 0.3333333333333333,
#                           'it': 0.3333333333333333}),
#              ('.',
#               'each'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'player': 0.3333333333333333,
#                           'year': 0.3333333333333333,
#                           'event': 0.3333333333333333}),
#              ('each',
#               'player'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'uses': 0.3333333333333333,
#                           'making': 0.3333333333333333,
#                           'plays': 0.3333333333333333}),
#              ('player',
#               'uses'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 1.0}),
#              ('uses',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'tennis': 1.0}),
#              ('a',
#               'tennis'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'racket': 0.5,
#                           'court': 0.25,
#                           'game': 0.25}),
#              ('tennis',
#               'racket'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'that': 0.5,
#                           'include': 0.5}),
#              ('racket',
#               'that'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'is': 1.0}),
#              ('that',
#               'is'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'strung': 0.3333333333333333,
#                           'not': 0.3333333333333333,
#                           'adjusted': 0.3333333333333333}),
#              ('is',
#               'strung'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'with': 1.0}),
#              ('strung',
#               'with'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'cord': 1.0}),
#              ('with',
#               'cord'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'to': 1.0}),
#              ('cord',
#               'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'strike': 1.0}),
#              ('to',
#               'strike'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 1.0}),
#              ('strike',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'hollow': 1.0}),
#              ('a',
#               'hollow'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'rubber': 1.0}),
#              ('hollow',
#               'rubber'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'ball': 1.0}),
#              ('rubber',
#               'ball'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'covered': 1.0}),
#              ('ball',
#               'covered'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'with': 1.0}),
#              ('covered',
#               'with'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'felt': 1.0}),
#              ('with',
#               'felt'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'over': 1.0}),
#              ('felt',
#               'over'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'or': 1.0}),
#              ('over',
#               'or'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'around': 1.0}),
#              ('or',
#               'around'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 1.0}),
#              ('around',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'net': 1.0}),
#              ('a',
#               'net'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'and': 0.2,
#                           'poles': 0.2,
#                           'is': 0.2,
#                           'judge': 0.4}),
#              ('net',
#               'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'into': 0.25,
#                           'ahead': 0.25,
#                           'is': 0.25,
#                           'played': 0.25}),
#              ('and',
#               'into'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'the': 1.0}),
#              ('into',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'opponents': 0.25,
#                           'area': 0.08333333333333333,
#                           'diagonally': 0.16666666666666666,
#                           'other': 0.16666666666666666,
#                           'opposite': 0.08333333333333333,
#                           'shot': 0.08333333333333333,
#                           'air': 0.08333333333333333,
#                           'correct': 0.08333333333333333}),
#              ('the',
#               'opponents'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'court': 0.8,
#                           'head': 0.2}),
#              ('opponents',
#               'court'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'.':
#                           'doubles': 0.010752688172043012,
#                           'baseline': 0.010752688172043012,
#                           'net': 0.043010752688172046,
#                           'server.for': 0.010752688172043012,
#                           'service': 0.021505376344086023,
#                           'center': 0.010752688172043012,
#                           'set': 0.021505376344086023,
#                           'olympic': 0.010752688172043012,
#                           'match': 0.03225806451612903,
#                           'server': 0.021505376344086023,
#                           'previous': 0.010752688172043012,
#                           'delay': 0.010752688172043012,
#                           'balls': 0.010752688172043012,
#                           'shot': 0.043010752688172046,
#                           'three': 0.010752688172043012,
#                           'other': 0.010752688172043012,
#                           'body': 0.03225806451612903,
#                           'racket': 0.010752688172043012,
#                           'worlds': 0.010752688172043012,
#                           'opponents': 0.010752688172043012,
#                           'air': 0.010752688172043012,
#                           'most': 0.010752688172043012,
#                           'grand': 0.010752688172043012,
#                           'tennis': 0.010752688172043012,
#                           'number': 0.010752688172043012,
#                           'series': 0.010752688172043012,
#                           'nine': 0.010752688172043012,
#                           'wta': 0.010752688172043012,
#                           'very': 0.010752688172043012,
#                           'mens': 0.010752688172043012,
#                           'players': 0.010752688172043012,
#                           'greatest': 0.010752688172043012,
#                           'top': 0.010752688172043012,
#                           'twentieth': 0.010752688172043012}),
#              ('the',
#               'game'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'is': 0.18181818181818182,
#                           'was': 0.09090909090909091,
#                           'began': 0.045454545454545456,
#                           'of': 0.09090909090909091,
#                           'and': 0.09090909090909091,
#                           'can': 0.045454545454545456,
#                           'tying': 0.045454545454545456,
#                           'needs': 0.045454545454545456,
#                           '.': 0.18181818181818182,
#                           'with': 0.045454545454545456,
#                           'has': 0.045454545454545456,
#                           'in': 0.045454545454545456,
#                           'so': 0.045454545454545456}),
#              ('game',
#               'is'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'to': 0.14285714285714285,
#                           'won': 0.14285714285714285,
#                           'described': 0.14285714285714285,
#                           'advantage': 0.14285714285714285,
#                           'played': 0.14285714285714285,
#                           'awarded': 0.14285714285714285,
#                           'also': 0.14285714285714285}),
#              ('is',
#               'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'maneuver': 0.3333333333333333,
#                           'assign': 0.3333333333333333,
#                           'allow': 0.3333333333333333}),
#              ('to',
#               'maneuver'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'the': 1.0}),
#              ('maneuver',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'ball': 1.0}),
#              ('the',
#               'ball'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'in': 0.06060606060606061,
#                           'will': 0.030303030303030304,
#                           'could': 0.030303030303030304,
#                           'into': 0.12121212121212122,
#                           'must': 0.06060606060606061,
#                           'hits': 0.06060606060606061,
#                           'is': 0.09090909090909091,
#                           'across': 0.030303030303030304,
#                           'so': 0.030303030303030304,
#                           'twice': 0.030303030303030304,
#                           'has': 0.06060606060606061,
#                           'and': 0.12121212121212122,
#                           'opposite': 0.030303030303030304,
#                           'to': 0.06060606060606061,
#                           '.': 0.030303030303030304,
#                           'bounces': 0.030303030303030304,
#                           'on': 0.030303030303030304,
#                           'high': 0.030303030303030304,
#                           'or': 0.030303030303030304,
#                           'just': 0.030303030303030304}),
#              ('ball',
#               'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'such': 0.5,
#                           'boston': 0.5}),
#              ('in',
#               'such'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 0.5,
#                           'cases': 0.5}),
#              ('such',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'way': 1.0}),
#              ('a',
#               'way'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'that': 0.5,
#                           'of': 0.5}),
#              ('way',
#               'that'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'the': 1.0}),
#              ('that',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'opponent': 0.3333333333333333,
#                           'games': 0.16666666666666666,
#                           'company': 0.16666666666666666,
#                           'loser': 0.16666666666666666,
#                           'ball': 0.16666666666666666}),
#              ('the',
#               'opponent'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'is': 0.375,
#                           '.': 0.25,
#                           'five': 0.125,
#                           'in': 0.125,
#                           'as': 0.125}),
#              ('opponent',
#               'is'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'not': 0.25,
#                           'called': 0.25,
#                           'deep': 0.25,
#                           'unable': 0.25}),
#              ('is',
#               'not'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'able': 0.16666666666666666,
#                           'where': 0.16666666666666666,
#                           'called': 0.16666666666666666,
#                           'sanctioned': 0.16666666666666666,
#                           'touched': 0.16666666666666666,
#                           'hit': 0.16666666666666666}),
#              ('not',
#               'able'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'to': 1.0}),
#              ('able',
#               'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'play': 0.3333333333333333,
#                           'make': 0.3333333333333333,
#                           'return': 0.3333333333333333}),
#              ('to',
#               'play'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 0.14285714285714285,
#                           'against': 0.14285714285714285,
#                           'in': 0.14285714285714285,
#                           'the': 0.14285714285714285,
#                           '.': 0.14285714285714285,
#                           'backhand': 0.14285714285714285,
#                           'doubles': 0.14285714285714285}),
#              ('play',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'valid': 0.5,
#                           'player': 0.5}),
#              ('a',
#               'valid'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'return': 1.0}),
#              ('valid',
#               'return'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'.': 1.0}),
#              ('return',
#               '.'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'the': 1.0}),
#              ('the',
#               'player'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'who': 0.26666666666666666,
#                           'can': 0.06666666666666667,
#                           'in': 0.06666666666666667,
#                           'wins': 0.06666666666666667,
#                           'has': 0.13333333333333333,
#                           'entitled': 0.06666666666666667,
#                           'to': 0.06666666666666667,
#                           'crouching': 0.06666666666666667,
#                           'more': 0.06666666666666667,
#                           'long': 0.06666666666666667,
#                           'approaches': 0.06666666666666667}),
#              ('player',
#               'who'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'is': 1.0}),
#              ('who',
#               'is'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'unable': 0.14285714285714285,
#                           'in': 0.14285714285714285,
#                           'serving': 0.14285714285714285,
#                           'usually': 0.14285714285714285,
#                           'still': 0.14285714285714285,
#                           'consistently': 0.14285714285714285,
#                           'the': 0.14285714285714285}),
#              ('is',
#               'unable'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'to': 1.0}),
#              ('unable',
#               'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'return': 0.5,
#                           'run': 0.5}),
#              ('to',
#               'return'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'the': 0.5,
#                           'a': 0.5}),
#              ('return',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'ball': 1.0}),
#              ('ball',
#               'will'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'not': 1.0}),
#              ('will',
#               'not'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'gain': 1.0}),
#              ('not',
#               'gain'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 1.0}),
#              ('gain',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'point': 1.0}),
#              ('a',
#               'point'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'while': 0.2,
#                           'a': 0.2,
#                           'and': 0.2,
#                           '.': 0.2,
#                           'event': 0.2}),
#              ('point',
#               'while'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'the': 1.0}),
#              ('while',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'opposite': 0.25,
#                           'women': 0.25,
#                           'atp': 0.25,
#                           'doubles': 0.25}),
#              ('the',
#               'opposite'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'player': 0.5,
#                           'side': 0.5}),
#              ('opposite',
#               'player'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'will.tennis': 1.0}),
#              ('player',
#               'will.tennis'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'is': 1.0}),
#              ('will.tennis',
#               'is'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'an': 1.0}),
#              ('is',
#               'an'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'olympic': 0.3333333333333333,
#                           'officiating': 0.3333333333333333,
#                           'offensive': 0.3333333333333333}),
#              ('an',
#               'olympic'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'sport': 0.5,
#                           'medal': 0.5}),
#              ('olympic',
#               'sport'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'and': 1.0}),
#              ('sport',
#               'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'is': 1.0}),
#              ('and',
#               'is'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'played': 0.125,
#                           'also': 0.125,
#                           'a': 0.125,
#                           'now': 0.125,
#                           'generally': 0.125,
#                           'usually': 0.125,
#                           'regarded': 0.25}),
#              ('is',
#               'played'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'at': 0.125,
#                           'by': 0.125,
#                           'on': 0.25,
#                           '.': 0.25,
#                           'with': 0.125,
#                           'the': 0.125}),
#              ('played',
#               'at'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'all': 1.0}),
#              ('at',
#               'all'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'levels': 0.16666666666666666,
#                           'ages': 0.16666666666666666,
#                           'times': 0.16666666666666666,
#                           'four': 0.16666666666666666,
#                           'other': 0.16666666666666666,
#                           'tournaments': 0.16666666666666666}),
#              ('all',
#               'levels'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'of': 0.5,
#                           '.': 0.5}),
#              ('levels',
#               'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'society': 1.0}),
#              ('of',
#               'society'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'and': 1.0}),
#              ('society',
#               'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'at': 1.0}),
#              ('and',
#               'at'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'all': 0.25,
#                           'least': 0.5,
#                           'the': 0.25}),
#              ('all',
#               'ages'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'.': 1.0}),
#              ('ages',
#               '.'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'the': 1.0}),
#              ('the',
#               'sport'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'can': 0.5,
#                           'has': 0.5}),
#              ('sport',
#               'can'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'be': 1.0}),
#              ('played',
#               'by'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'anyone': 0.3333333333333333,
#                           'millions': 0.3333333333333333,
#                           'ablebodied': 0.3333333333333333}),
#              ('by',
#               'anyone'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'who': 1.0}),
#              ('anyone',
#               'who'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'can': 1.0}),
#              ('who',
#               'can'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'hold': 1.0}),
#              ('can',
#               'hold'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 1.0}),
#              ('hold',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'racket': 1.0}),
#              ('racket',
#               'including'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'wheelchair': 1.0}),
#              ('including',
#               'wheelchair'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'users': 1.0}),
#              ('wheelchair',
#               'users'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'.': 0.5,
#                           'only.in': 0.5}),
#              ('users',
#               '.'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'the': 1.0}),
#              ('the',
#               'modern'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'game': 0.6666666666666666,
#                           'style': 0.3333333333333333}),
#              ('modern',
#               'game'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'of': 0.5,
#                           'rackets': 0.5}),
#              ('game',
#               'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'tennis': 0.5,
#                           'the': 0.25,
#                           'lawn': 0.25}),
#              ('of',
#               'tennis'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'originated': 0.1111111111111111,
#                           'after': 0.1111111111111111,
#                           'memorabilia': 0.1111111111111111,
#                           'stems': 0.1111111111111111,
#                           'the': 0.1111111111111111,
#                           'must': 0.1111111111111111,
#                           'is': 0.1111111111111111,
#                           'professionals': 0.1111111111111111,
#                           'former': 0.1111111111111111}),
#              ('tennis',
#               'originated'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'in': 1.0}),
#              ('originated',
#               'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'birmingham': 1.0}),
#              ('in',
#               'birmingham'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'england': 0.3333333333333333,
#                           'in': 0.6666666666666666}),
#              ('birmingham',
#               'england'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'in': 1.0}),
#              ('england',
#               'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'the': 1.0}),
#              ('in',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'late': 0.019230769230769232,
#                           's.': 0.019230769230769232,
#                           'modern': 0.019230769230769232,
#                           'first': 0.038461538461538464,
#                           'world': 0.057692307692307696,
#                           'ensuing': 0.019230769230769232,
#                           'major': 0.019230769230769232,
#                           'hopes': 0.019230769230769232,
#                           'latter': 0.038461538461538464,
#                           'united': 0.019230769230769232,
#                           'far': 0.019230769230769232,
#                           'region': 0.019230769230769232,
#                           'proximal': 0.019230769230769232,
#                           'center': 0.038461538461538464,
#                           'service': 0.019230769230769232,
#                           'servers': 0.019230769230769232,
#                           'lead': 0.038461538461538464,
#                           'us': 0.038461538461538464,
#                           'final': 0.019230769230769232,
#                           'game': 0.019230769230769232,
#                           'following': 0.019230769230769232,
#                           'tiebreak': 0.019230769230769232,
#                           'chair.ball': 0.019230769230769232,
#                           'future': 0.019230769230769232,
#                           'junior': 0.019230769230769232,
#                           'box.experienced': 0.019230769230769232,
#                           's': 0.057692307692307696,
#                           'vicinity': 0.019230769230769232,
#                           'air': 0.019230769230769232,
#                           'regular': 0.019230769230769232,
#                           'four': 0.019230769230769232,
#                           'next': 0.019230769230769232,
#                           'singles': 0.038461538461538464,
#                           'worlds': 0.019230769230769232,
#                           'atp': 0.057692307692307696,
#                           'directors': 0.019230769230769232,
#                           'doubles': 0.019230769230769232,
#                           'olympics': 0.019230769230769232,
#                           'history': 0.038461538461538464}),
#              ('the',
#               'late'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'th': 0.5,
#                           's': 0.5}),
#              ('late',
#               'th'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'century': 1.0}),
#              ('th',
#               'century'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'as': 0.16666666666666666,
#                           'in': 0.08333333333333333,
#                           'northern': 0.08333333333333333,
#                           '.': 0.16666666666666666,
#                           'that': 0.08333333333333333,
#                           'until': 0.08333333333333333,
#                           'to': 0.08333333333333333,
#                           'the': 0.08333333333333333,
#                           'by': 0.08333333333333333,
#                           'directly': 0.08333333333333333}),
#              ('century',
#               'as'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'lawn': 0.5,
#                           'shotmaking': 0.5}),
#              ('as',
#               'lawn'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'tennis': 1.0}),
#              ('lawn',
#               'tennis'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'.': 0.1,
#                           'most': 0.1,
#                           'was': 0.1,
#                           'appears': 0.1,
#                           'for': 0.1,
#                           'club': 0.1,
#                           'and': 0.1,
#                           'association': 0.2,
#                           'federation': 0.1}),
#              ('tennis',
#               '.'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'it': 0.09090909090909091,
#                           'during': 0.18181818181818182,
#                           'according': 0.09090909090909091,
#                           'together': 0.09090909090909091,
#                           'with': 0.09090909090909091,
#                           'the': 0.09090909090909091,
#                           'when': 0.09090909090909091,
#                           'in': 0.09090909090909091,
#                           'each': 0.09090909090909091,
#                           'he': 0.09090909090909091}),
#              ('.',
#               'it'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'had': 0.06666666666666667,
#                           'was': 0.06666666666666667,
#                           'is': 0.6,
#                           'allows': 0.13333333333333333,
#                           'can': 0.06666666666666667,
#                           'ranked': 0.06666666666666667}),
#              ('it',
#               'had'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'close': 1.0}),
#              ('had',
#               'close'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'connections': 1.0}),
#              ('close',
#               'connections'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'both': 1.0}),
#              ('connections',
#               'both'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'to': 1.0}),
#              ('both',
#               'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'various': 1.0}),
#              ('to',
#               'various'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'field': 1.0}),
#              ('various',
#               'field'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'lawn': 1.0}),
#              ('field',
#               'lawn'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'games': 1.0}),
#              ('lawn',
#               'games'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'such': 1.0}),
#              ('games',
#               'such'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'as': 1.0}),
#              ('such',
#               'as'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'croquet': 0.08333333333333333,
#                           'titanium': 0.08333333333333333,
#                           'at': 0.08333333333333333,
#                           'australian': 0.08333333333333333,
#                           'rain': 0.08333333333333333,
#                           'monica': 0.08333333333333333,
#                           'wheelchair': 0.08333333333333333,
#                           'golf': 0.08333333333333333,
#                           'martina': 0.08333333333333333,
#                           'jamie': 0.08333333333333333,
#                           'boris': 0.08333333333333333,
#                           'wimbledon': 0.08333333333333333}),
#              ('as',
#               'croquet'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'and': 1.0}),
#              ('croquet',
#               'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'bowls': 1.0}),
#              ('and',
#               'bowls'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'as': 1.0}),
#              ('bowls',
#               'as'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'well': 1.0}),
#              ('as',
#               'well'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'as': 0.8,
#                           '.': 0.2}),
#              ('well',
#               'as'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'to': 0.25,
#                           'a': 0.25,
#                           'people': 0.25,
#                           'being': 0.25}),
#              ('as',
#               'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'the': 1.0}),
#              ('to',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'older': 0.027777777777777776,
#                           'server': 0.027777777777777776,
#                           'codification': 0.027777777777777776,
#                           'abandonment': 0.027777777777777776,
#                           'use': 0.027777777777777776,
#                           'following': 0.027777777777777776,
#                           'court': 0.05555555555555555,
#                           'inside': 0.027777777777777776,
#                           'pace': 0.027777777777777776,
#                           'other': 0.027777777777777776,
#                           'receiver': 0.08333333333333333,
#                           'canadian': 0.027777777777777776,
#                           'mark': 0.027777777777777776,
#                           'players': 0.027777777777777776,
#                           'atp': 0.027777777777777776,
#                           'way': 0.027777777777777776,
#                           'net': 0.08333333333333333,
#                           'stroke': 0.05555555555555555,
#                           'coiling': 0.027777777777777776,
#                           'front': 0.027777777777777776,
#                           'opponent': 0.027777777777777776,
#                           'ground': 0.027777777777777776,
#                           'lengthened': 0.027777777777777776,
#                           'champion': 0.027777777777777776,
#                           'tour': 0.027777777777777776,
#                           'masters': 0.027777777777777776,
#                           'number': 0.027777777777777776,
#                           'amount': 0.027777777777777776,
#                           'list': 0.027777777777777776,
#                           'one': 0.027777777777777776}),
#              ('the',
#               'older'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'racket': 1.0}),
#              ('older',
#               'racket'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'sport': 1.0}),
#              ('sport',
#               'today'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'called': 1.0}),
#              ('today',
#               'called'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'real': 1.0}),
#              ('called',
#               'real'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'tennis': 1.0}),
#              ('real',
#               'tennis'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'.': 0.4,
#                           'not': 0.2,
#                           'and': 0.2,
#                           'declined': 0.2}),
#              ('.',
#               'during'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'most': 0.3333333333333333,
#                           'the': 0.3333333333333333,
#                           'informal': 0.3333333333333333}),
#              ('during',
#               'most'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'of': 1.0}),
#              ('most',
#               'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'the': 1.0}),
#              ('the',
#               'th'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'century': 0.8333333333333334,
#                           'and': 0.08333333333333333,
#                           'anniversary': 0.08333333333333333}),
#              ('century',
#               'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'fact': 1.0}),
#              ('in',
#               'fact'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'the': 0.5,
#                           'win': 0.5}),
#              ('fact',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'term': 1.0}),
#              ('the',
#               'term'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'tennis': 0.3333333333333333,
#                           'hard': 0.3333333333333333,
#                           'doubles': 0.3333333333333333}),
#              ('term',
#               'tennis'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'referred': 1.0}),
#              ('tennis',
#               'referred'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'to': 1.0}),
#              ('referred',
#               'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'real': 0.125,
#                           'as': 0.875}),
#              ('to',
#               'real'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'tennis': 1.0}),
#              ('tennis',
#               'not'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'lawn': 1.0}),
#              ('not',
#               'lawn'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'tennis.the': 1.0}),
#              ('lawn',
#               'tennis.the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'rules': 1.0}),
#              ('tennis.the',
#               'rules'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'of': 1.0}),
#              ('rules',
#               'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'modern': 0.3333333333333333,
#                           'tennis': 0.6666666666666666}),
#              ('of',
#               'modern'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'tennis': 0.6666666666666666,
#                           'rules': 0.3333333333333333}),
#              ('modern',
#               'tennis'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'have': 0.14285714285714285,
#                           '.': 0.2857142857142857,
#                           'balls': 0.14285714285714285,
#                           'court': 0.14285714285714285,
#                           'open': 0.14285714285714285,
#                           'especially': 0.14285714285714285}),
#              ('tennis',
#               'have'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'changed': 1.0}),
#              ('have',
#               'changed'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'little': 0.5,
#                           'over': 0.5}),
#              ('changed',
#               'little'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'since': 1.0}),
#              ('little',
# ...
#              ('tennis',
#               'after'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'watching': 1.0}),
#              ('after',
#               'watching'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'british': 1.0}),
#              ('watching',
#               'british'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'army': 1.0}),
#              ('army',
#               'officers'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'play': 1.0}),
#              ('officers',
#               'play'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'.': 1.0}),
#              ('play',
#               '.'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'she': 0.14285714285714285,
#                           'beginners': 0.14285714285714285,
#                           'the': 0.42857142857142855,
#                           'talented': 0.14285714285714285,
#                           'any': 0.14285714285714285}),
#              ('she',
#               'laid'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'out': 1.0}),
#              ('laid',
#               'out'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 1.0}),
#              ('out',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'tennis': 1.0}),
#              ('tennis',
#               'court'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'at': 0.5,
#                           'owes': 0.5}),
#              ('court',
#               'at'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'the': 0.5,
#                           'a': 0.5}),
#              ('the',
#               'staten'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'island': 1.0}),
#              ('staten',
#               'island'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'cricket': 0.5,
#                           'new': 0.5}),
#              ('island',
#               'cricket'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'club': 1.0}),
#              ('cricket',
#               'club'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'at': 1.0}),
#              ('club',
#               'at'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'camp': 1.0}),
#              ('at',
#               'camp'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'washington': 1.0}),
#              ('camp',
#               'washington'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'tompkinsville': 1.0}),
#              ('washington',
#               'tompkinsville'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'staten': 1.0}),
#              ('tompkinsville',
#               'staten'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'island': 1.0}),
#              ('island',
#               'new'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'york': 1.0}),
#              ('new',
#               'york'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'.': 1.0}),
#              ('york',
#               '.'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'the': 1.0}),
#              ('first',
#               'american'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'national': 1.0}),
#              ('american',
#               'national'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'championship': 1.0}),
#              ('national',
#               'championship'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'was': 1.0}),
#              ('championship',
#               'was'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'played': 0.3333333333333333,
#                           'dropped': 0.3333333333333333,
#                           'created': 0.3333333333333333}),
#              ('was',
#               'played'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'there': 1.0}),
#              ('played',
#               'there'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'in': 1.0}),
#              ('there',
#               'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'september': 1.0}),
#              ('in',
#               'september'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'.': 1.0}),
#              ('september',
#               '.'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'an': 1.0}),
#              ('.',
#               'an'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'englishman': 0.5,
#                           'extra': 0.5}),
#              ('an',
#               'englishman'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'named': 1.0}),
#              ('englishman',
#               'named'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'o.e': 1.0}),
#              ('named',
#               'o.e'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'.': 1.0}),
#              ('o.e',
#               '.'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'woodhouse': 1.0}),
#              ('.',
#               'woodhouse'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'won': 1.0}),
#              ('woodhouse',
#               'won'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'the': 1.0}),
#              ('won',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'singles': 0.5,
#                           'calendar': 0.5}),
#              ('the',
#               'singles'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'title': 0.1111111111111111,
#                           'court': 0.1111111111111111,
#                           'sidelines': 0.1111111111111111,
#                           'player': 0.1111111111111111,
#                           'draws': 0.1111111111111111,
#                           'draw': 0.2222222222222222,
#                           'competition': 0.1111111111111111,
#                           'winner': 0.1111111111111111}),
#              ('singles',
#               'title'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'and': 1.0}),
#              ('title',
#               'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 1.0}),
#              ('a',
#               'silver'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'cup': 1.0}),
#              ('silver',
#               'cup'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'worth': 1.0}),
#              ('cup',
#               'worth'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'by': 1.0}),
#              ('worth',
#               'by'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'defeating': 1.0}),
#              ('by',
#               'defeating'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'canadian': 1.0}),
#              ('defeating',
#               'canadian'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i.': 1.0}),
#              ('canadian',
#               'i.'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'f.': 1.0}),
#              ('i.',
#               'f.'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'hellmuth': 1.0}),
#              ('f.',
#               'hellmuth'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'.': 1.0}),
#              ('hellmuth',
#               '.'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'there': 1.0}),
#              ('.',
#               'there'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'was': 0.1111111111111111,
#                           'were': 0.1111111111111111,
#                           'is': 0.1111111111111111,
#                           'also': 0.1111111111111111,
#                           'are': 0.4444444444444444,
#                           'can': 0.1111111111111111}),
#              ('a',
#               'doubles'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'match': 0.16666666666666666,
#                           'sideline': 0.16666666666666666,
#                           'team': 0.5,
#                           'pairing': 0.16666666666666666}),
#              ('doubles',
#               'match'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'which': 1.0}),
#              ('match',
#               'which'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'was': 1.0}),
#              ('which',
#               'was'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'won': 1.0}),
#              ('was',
#               'won'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'by': 1.0}),
#              ('won',
#               'by'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 0.5,
#                           'the': 0.5}),
#              ('a',
#               'local'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'pair': 1.0}),
#              ('local',
#               'pair'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'.': 1.0}),
#              ('pair',
#               '.'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'there': 1.0}),
#              ('there',
#               'were'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'different': 1.0}),
#              ('were',
#               'different'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'rules': 1.0}),
#              ('different',
#               'rules'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'at': 1.0}),
#              ('rules',
#               'at'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'each': 1.0}),
#              ('at',
#               'each'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'club': 1.0}),
#              ('each',
#               'club'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'.': 1.0}),
#              ('club',
#               '.'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'the': 1.0}),
#              ('in',
#               'boston'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'was': 1.0}),
#              ('boston',
#               'was'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'larger': 1.0}),
#              ('was',
#               'larger'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'than': 1.0}),
#              ('larger',
#               'than'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'the': 1.0}),
#              ('than',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'one': 0.14285714285714285,
#                           'opponent': 0.2857142857142857,
#                           'allowed': 0.14285714285714285,
#                           'forehand': 0.14285714285714285,
#                           'reach': 0.14285714285714285,
#                           'lower': 0.14285714285714285}),
#              ('the',
#               'one'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'normally': 0.3333333333333333,
#                           'major': 0.3333333333333333,
#                           'published': 0.3333333333333333}),
#              ('one',
#               'normally'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'used': 1.0}),
#              ('normally',
#               'used'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'in': 1.0}),
#              ('used',
#               'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'new': 0.5,
#                           'modern': 0.5}),
#              ('in',
#               'new'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'york.on': 1.0}),
#              ('new',
#               'york.on'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'may': 1.0}),
#              ('york.on',
#               'may'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'the': 1.0}),
#              ('may',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'oldest': 1.0}),
#              ('the',
#               'oldest'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nationwide': 1.0}),
#              ('oldest',
#               'nationwide'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'tennis': 1.0}),
#              ('nationwide',
#               'tennis'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'organization': 1.0}),
#              ('tennis',
#               'organization'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'in': 1.0}),
#              ('organization',
#               'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'the': 1.0}),
#              ('world',
#               'was'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'formed': 1.0}),
#              ('was',
#               'formed'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'the': 1.0}),
#              ('formed',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'united': 1.0}),
#              ('the',
#               'united'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'states': 1.0}),
#              ('united',
#               'states'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'national': 0.16666666666666666,
#                           'tennis': 0.5,
#                           'and': 0.3333333333333333}),
#              ('states',
#               'national'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'lawn': 1.0}),
#              ('national',
#               'lawn'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'tennis': 1.0}),
#              ('tennis',
#               'association'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'now': 0.14285714285714285,
#                           'in': 0.14285714285714285,
#                           'wta': 0.14285714285714285,
#                           'administers': 0.14285714285714285,
#                           'wimbledon': 0.14285714285714285,
#                           'us': 0.14285714285714285,
#                           'tour': 0.14285714285714285}),
#              ('association',
#               'now'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'the': 1.0}),
#              ('now',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'united': 0.3333333333333333,
#                           'us': 0.3333333333333333,
#                           'international': 0.3333333333333333}),
#              ('states',
#               'tennis'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'association': 1.0}),
#              ('association',
#               'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'order': 1.0}),
#              ('in',
#               'order'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'to': 0.875,
#                           'for': 0.125}),
#              ('order',
#               'to'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'standardize': 0.14285714285714285,
#                           'best': 0.14285714285714285,
#                           'achieve': 0.14285714285714285,
#                           'play': 0.14285714285714285,
#                           'increase': 0.2857142857142857,
#                           'hit': 0.14285714285714285}),
#              ('to',
#               'standardize'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'the': 1.0}),
#              ('standardize',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'rules': 1.0}),
#              ...})

# %% [markdown]
# ---
# # Provide the input

# %%
text_input = input('Enter the Text (Only 2 Words are Required) :')
text_tokenized = text_input.split(sep = ' ')
# Out:
# Enter the Text (Only 2 Words are Required) :cricket is

# %%
token_length = len(text_tokenized)

# %%
values_3_gram = model_3_gram.get((text_tokenized[token_length-2], text_tokenized[token_length-1]), '<NA>')
values_3_gram
# Out:
# '<NA>'

# %%
if(values_3_gram == '<NA>'):
    pred_ngrams = dict(model_2_gram[text_tokenized[token_length-1]])
else:
    pred_ngrams = dict(model_3_gram[text_tokenized[token_length-2],text_tokenized[token_length - 1]])

# %%
pred_ngrams
# Out:
# {'a': 0.07909604519774012,
#  'strung': 0.005649717514124294,
#  'to': 0.01694915254237288,
#  'not': 0.03389830508474576,
#  'unable': 0.011299435028248588,
#  'an': 0.01694915254237288,
#  'played': 0.04519774011299435,
#  'also': 0.03954802259887006,
#  'historys': 0.005649717514124294,
#  'now': 0.01694915254237288,
#  'believed': 0.005649717514124294,
#  'where': 0.005649717514124294,
#  'acknowledged': 0.005649717514124294,
#  'due': 0.005649717514124294,
#  'feet': 0.011299435028248588,
#  'required': 0.022598870056497175,
#  'stretched': 0.005649717514124294,
#  'held': 0.011299435028248588,
#  'unusual': 0.005649717514124294,
#  'used': 0.011299435028248588,
#  'referred': 0.011299435028248588,
#  'called': 0.03954802259887006,
#  'out': 0.011299435028248588,
#  'often': 0.011299435028248588,
#  'designated': 0.005649717514124294,
#  'the': 0.0903954802259887,
#  'decided': 0.005649717514124294,
#  'ready': 0.005649717514124294,
#  'void': 0.005649717514124294,
#  'hit': 0.01694915254237288,
#  'in': 0.01694915254237288,
#  'considered': 0.02824858757062147,
#  'won': 0.005649717514124294,
#  'described': 0.005649717514124294,
#  'advantage': 0.005649717514124294,
#  'ahead': 0.005649717514124294,
#  'ahead.the': 0.005649717514124294,
#  'always': 0.011299435028248588,
#  'determined': 0.005649717514124294,
#  'extended': 0.005649717514124294,
#  'serving': 0.005649717514124294,
#  'generally': 0.011299435028248588,
#  'awarded': 0.005649717514124294,
#  'said': 0.005649717514124294,
#  'permitted': 0.01694915254237288,
#  'possible': 0.005649717514124294,
#  'sure': 0.011299435028248588,
#  'usually': 0.01694915254237288,
#  'on': 0.005649717514124294,
#  'out.in': 0.005649717514124294,
#  'still': 0.005649717514124294,
#  'intended': 0.005649717514124294,
#  'increased': 0.005649717514124294,
#  'consistently': 0.005649717514124294,
#  'resumed': 0.01694915254237288,
#  'done': 0.005649717514124294,
#  'selected': 0.005649717514124294,
#  'strongly': 0.005649717514124294,
#  'sometimes': 0.011299435028248588,
#  'rotated': 0.005649717514124294,
#  'that': 0.005649717514124294,
#  'commonly': 0.011299435028248588,
#  'somewhere': 0.005649717514124294,
#  'placed': 0.005649717514124294,
#  'rare': 0.005649717514124294,
#  'positioned': 0.005649717514124294,
#  'behind': 0.005649717514124294,
#  'initiated': 0.005649717514124294,
#  'spinning': 0.005649717514124294,
#  'made': 0.01694915254237288,
#  'higher': 0.005649717514124294,
#  'deep': 0.005649717514124294,
#  'one': 0.011299435028248588,
#  'given': 0.005649717514124294,
#  'adjusted': 0.005649717514124294,
#  'composed': 0.011299435028248588,
#  'worth': 0.005649717514124294,
#  'currently': 0.005649717514124294,
#  'mandatory': 0.005649717514124294,
#  'more': 0.005649717514124294,
#  'who': 0.005649717514124294,
#  'regarded': 0.022598870056497175,
#  'definitely': 0.005649717514124294}

# %%
import random
# Generating a random number
rand_no = random.uniform(0, 1)
print('rand_no',rand_no)

import numpy as np
position = np.where(np.array(list(pred_ngrams.values())).cumsum() > rand_no)[0][0]
print('position',position)
# Out:
# rand_no 0.36483716388469767
# position 20

# %%
list(pred_ngrams.keys())[position]
# Out:
# 'referred'

# %% [markdown]
# ---
# # Suggested Next Word

# %%
print('Next Suggested Word is :', list(pred_ngrams.keys())[position])
# Out:
# Next Suggested Word is : referred
